# %% [markdown]
# ## Question 1 - Name Jupyter Notebook Files (10 pts)
# Name your Jupyter Notebook file as Lab5 followed by your first initial and last name (e.g. Lab5-wnimeister.ipynb).
# ***
# File named Lab5-DBaron.ipynb

# %% [markdown]
# ## Question 2 - Markdown Styling (10 pts)
# Add a new Markdown cell below and add Markdown for:
# - A title for the notebook.
# - A bullet list with:
#     - A **bold** word for Author: and then add text for your name.
#     - A **bold** word for Date: and then add text for today’s date.
# ***

# %% [markdown]
# # GTECH78518 Lab 5: Working with Numpy Arrays
# - **Author:** Deana Baron
# - **Date:** 2/22/19

# %% [markdown]
# ## Question 3 - Import Necessary Python Packages (10 pts)
#
# You will use the following Python packages to download data, read the data into numpy array:
# - os package. os
# - import numpy as np
# - import urllib.request
# - import matplotlib.pyplot as plt
# ***
# Import the necessary Python packages for this lab analysis (os, numpy, urllib.request, and matplotlib).

# %%
# import the necessary Python libraries for this lab

import os
import numpy as np
import urllib.request
import matplotlib.pyplot as plt

# print success statement when the import is complete
print ("Successfully imported the necessary libraries!")
# Out:
# Successfully imported the necessary libraries!

# %% [markdown]
# ## Question 4 - Set working directiory (10 pts)
#
# - use os.chdir() to set current working directory.
# - use os.getcwd() to check current workign directory
# ***
# The current working directory will be /Users/dbaron/Documents on this computer. The os library will be used to set and check that this is correct.

# %%
# set the current working directory
os.chdir("C:\\Users\\dbaron\\Documents")

# print the current working directory to make sure it is correct
os.getcwd()
# Out:
# 'C:\\Users\\dbaron\\Documents'

# %% [markdown]
# ## Question 5 - Download CSV File (10 pts)
#
# Use `urllib.request` to download the anuual temperature and precipitation data from 1869 - 2017 for Central Park, NY to your data directory. The location of the data is
# - http://www.geography.hunter.cuny.edu/~wenge/AnnualTemperature.csv
# - http://www.geography.hunter.cuny.edu/~wenge/AnnualPrecipitation.csv
# ***
# The data is located on the professor's website, so we can use the urllib.request library to download the data directly from the website, and later convert this to numpy arrays to work with it easily.

# %%
# download temperature and precipitation csv files from website

# first download csv file containing the temperature values
urllib.request.urlretrieve(url = "http://www.geography.hunter.cuny.edu/~wenge/AnnualTemperature.csv",
                          filename = "AnnualTemperature.csv")

# then download csv file containing the precipitation values
urllib.request.urlretrieve(url = "http://www.geography.hunter.cuny.edu/~wenge/AnnualPrecipitation.csv",
                          filename = "AnnualPrecipitation.csv")

# print message to show that data downloads were successful
print ("Data downloads were a success!")
# Out:
# Data downloads were a success!

# %% [markdown]
# ## Question 6 -  Import Into Numpy Arrays (10 pts)
#
# Use the appropriate function to import the annual temperature and precipitation
# data into a numpy array.
# ***
# Now that the data is downloaded, we can convert the CSVs to numpy arrays so we can use numpy functions on them with ease. This allows for fast analysis and plotting of the data.

# %%
# import the data into a numpy array using the loadtxt function
annualtemp = np.loadtxt("AnnualTemperature.csv", delimiter = ",")
annualprecip = np.loadtxt("AnnualPrecipitation.csv", delimiter = ",")

# print a statement to show that the data was loaded successfully
print ("Data successfully imported into numpy arrays!")
# Out:
# Data successfully imported into numpy arrays!

# %% [markdown]
# ## Question 7 - Print Data From Numpy Arrays (10 pts)
# - Use .shape after the variable name of the numpy array (e.g. variablename.shape) to get its dimensions (i.e. number of rows and columns).
# - Print out the values of the first 10 rows and two columns of your array
# - Print out the values of the last 10 rows and two columns of your array
# ***
# To prove that the data has been loaded successfully, we can print out information about the data and a subset of the data.

# %%
# get the dimensions of the temperature and precipitation arrays
print (annualtemp.shape)
print (annualprecip.shape, "\n")

# print out the first 10 rows and two columns of each array (there are only two columns in the array so we can print all the columns)
print (annualtemp[0:10, :], "\n")
print (annualprecip[0:10, :], "\n")

# print out the last 10 rows and two columns of each array. use the last index 
print (annualtemp[139:149, :], "\n")
print (annualprecip[139:149, :])
# Out:
# (149, 2)
# (149, 2)
#
# [[1869.    51.4]
#  [1870.    53.6]
#  [1871.    51.1]
#  [1872.    51. ]
#  [1873.    51. ]
#  [1874.    51.3]
#  [1875.    49.4]
#  [1876.    51.9]
#  [1877.    52.8]
#  [1878.    53.6]]
#
# [[1869.     45.25]
#  [1870.     39.25]
#  [1871.     51.26]
#  [1872.     42.49]
#  [1873.     47.99]
#  [1874.     45.83]
#  [1875.     40.9 ]
#  [1876.     41.77]
#  [1877.     40.17]
#  [1878.     48.66]]
#
# [[2008.    55.3]
#  [2009.    54. ]
#  [2010.    56.7]
#  [2011.    56.4]
#  [2012.    57.3]
#  [2013.    55.3]
#  [2014.    54.4]
#  [2015.    56.7]
#  [2016.    57.2]
#  [2017.    56.3]]
#
# [[2008.     53.61]
#  [2009.     53.62]
#  [2010.     49.37]
#  [2011.     72.81]
#  [2012.     38.51]
#  [2013.     46.32]
#  [2014.     53.79]
#  [2015.     40.97]
#  [2016.     42.17]
#  [2017.     45.04]]

# %% [markdown]
# ## Question 8 - Run Calculations on Numpy Arrays (10 pts)
#
# - Convert the variable values from Fahrenheit to Celsius using the following equation:
# Celsius = (Fahrenheit - 32) / 1.8
# Precipitation (mm) = precipitaton (in)*25.4
# - Print out the values of the first 10 rows and two columns of your array
# - Print out the values of the last 10 rows and two columns of your array
# ***
# Now that the data is successfully imported into arrays, we can run calculations on the arrays, like converting the temperatures and precipitations into metric measurements.

# %%
# convert the temperature array to Celsius from Fahrenheit
annualtemp[:,1] = (annualtemp[:,1] - 32) / 1.8

# print out the first and last 10 rows and two columns of the temperature array
print (annualtemp[0:10, :], "\n")
print (annualtemp[139:149, :], "\n")
# Out:
# [[1869.           10.77777778]
#  [1870.           12.        ]
#  [1871.           10.61111111]
#  [1872.           10.55555556]
#  [1873.           10.55555556]
#  [1874.           10.72222222]
#  [1875.            9.66666667]
#  [1876.           11.05555556]
#  [1877.           11.55555556]
#  [1878.           12.        ]]
#
# [[2008.           12.94444444]
#  [2009.           12.22222222]
#  [2010.           13.72222222]
#  [2011.           13.55555556]
#  [2012.           14.05555556]
#  [2013.           12.94444444]
#  [2014.           12.44444444]
#  [2015.           13.72222222]
#  [2016.           14.        ]
#  [2017.           13.5       ]]

# %%
# convert the precipitation array from inches to millimeters
annualprecip[:,1] = (annualprecip[:,1] * 25.4)

# print out the first and last 10 rows and two columns of the precipitation array
print (annualprecip[0:10, :], "\n")
print (annualprecip[139:149, :], "\n")
# Out:
# [[1869.    1149.35 ]
#  [1870.     996.95 ]
#  [1871.    1302.004]
#  [1872.    1079.246]
#  [1873.    1218.946]
#  [1874.    1164.082]
#  [1875.    1038.86 ]
#  [1876.    1060.958]
#  [1877.    1020.318]
#  [1878.    1235.964]]
#
# [[2008.    1361.694]
#  [2009.    1361.948]
#  [2010.    1253.998]
#  [2011.    1849.374]
#  [2012.     978.154]
#  [2013.    1176.528]
#  [2014.    1366.266]
#  [2015.    1040.638]
#  [2016.    1071.118]
#  [2017.    1144.016]]

# %% [markdown]
# ## Question 9 - Calculate Summary Statistics of Numpy Array (10 pts)
# - Calculate the minmum, maximum, and mean and standard deviation of the annual temperature and precipitation data
# ***
# We can also calculate basic statistics on the arrays for better summarization of the data.

# %%
# calculate the min, max, mean, and standard deviation of the temperature data
temp = annualtemp[:,1] # convert to single array to allow for easier processing
mean_temp = np.mean(temp)
min_temp = np.min(temp)
max_temp = np.max(temp)
std_temp = np.std(temp)

# print out the values for temperature
print ("The average annual temperature is", mean_temp, "degrees Celsius.\n")
print ("The minimum temperature is", min_temp, "degrees Celsius.\n")
print ("The maximum temperature is", max_temp, "degrees Celsius.\n")
print ("The standard deviation of the temperature is", std_temp, "degrees Celsius.\n")
# Out:
# The average annual temperature is 12.190529455630125 degrees Celsius.
#
# The minimum temperature is 9.611111111111109 degrees Celsius.
#
# The maximum temperature is 14.055555555555554 degrees Celsius.
#
# The standard deviation of the temperature is 0.9373721921565789 degrees Celsius.

# %%
# calculate the min, max, mean, and standard deviation of the precipitation data
precip = annualprecip[:,1] # convert to single array to allow for easier processing
mean_precip = np.mean(precip)
min_precip = np.min(precip)
max_precip = np.max(precip)
std_precip = np.std(precip)

# print out the values for temperature
print ("The average annual precipitation is", mean_precip, "mm.\n")
print ("The minimum precipitation is", min_precip, "mm.\n")
print ("The maximum precipitation is", max_precip, "mm.\n")
print ("The standard deviation of the precipitation is", std_precip, "mm.\n")
# Out:
# The average annual precipitation is 1149.6057046979868 mm.
#
# The minimum precipitation is 662.6859999999999 mm.
#
# The maximum precipitation is 2046.224 mm.
#
# The standard deviation of the precipitation is 207.14492626889597 mm.

# %% [markdown]
# ## Question 10 - Plot the time series of the annual temperature and precipitation in two subplots (10 pts)
# - plot the time series of the annual temperature and precipitation data
# - Additional Resources on matplotlib:
#
#     * <a href="https://matplotlib.org/examples/pylab_examples/subplots_demo.html" target="_blank">More Matplotlib Examples</a>
#
#     * <a href="https://realpython.com/blog/python/python-matplotlib-guide/?utm_campaign=Data%2BElixir&utm_medium=email&utm_source=Data_Elixir_172" target="_blank">In-depth Guide to Matplotlib</a>
# ***
# Now we can plot the data to better communicate it to other audiences visually.

# %%
# Let's plot the numpy arrays on the same subplot!!

# set the plot size for these plots
plt.rcParams["figure.figsize"] = (12, 12)

# create the plot space with two subplots on it
fig, (ax1, ax2) = plt.subplots(2) # default `sharex = False`, it could be true because they are the same, I don't like how it looks

# add the x and y axes to the graph (scatter and line)
ax1.plot(annualtemp[:,0], annualtemp[:,1], "-o", color = "red")
ax2.plot(annualprecip[:,0], annualprecip[:,1], "-o", color = "blue")

# set the plot titles
ax1.set(title = "Time Series of Annual Temperature in Central Park, NY from 1868 to 2017 in Celcius")
ax2.set(title = "Time Series of Annual Precipitation in Central Park, NY from 1868 to 2017 in Millimeters")

# set the axes titles
ax1.set(xlabel = "Year", ylabel = "Temperature (degrees Celsius)")
ax2.set(xlabel = "Year", ylabel = "Precipitation (mm)");
